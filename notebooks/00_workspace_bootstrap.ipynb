# %% [markdown]
# # Workspace Bootstrap
#
# Load a reusable `AnalysisWorkspace` that every other notebook can build on.

# %%
from pathlib import Path
import sys

def find_repo_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / 'analysis_module').is_dir():
            return candidate
    return start

ROOT = find_repo_root(Path.cwd())
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

ROOT
# Out:
# PosixPath('/Users/alexstevens/Documents/GitHub/RSS_Feeds')

# %%
from analysis_module import load_workspace, lens_coverage

ws = load_workspace(
    scores_path=ROOT / 'scores.json',
    lenses_path=ROOT / 'lenses',
    aggregation='latest',
)

print('items:', len(ws.item_ids))
print('lenses:', len(ws.lens_names))
print('aggregation:', ws.aggregation)
print('coverage:', lens_coverage(ws, normalized=False))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from analysis_module import load_workspace, lens_coverage
# ----> 3 ws = load_workspace(
#       4     scores_path=ROOT / 'scores.json',
#       5     lenses_path=ROOT / 'lenses',
#       6     aggregation='latest',
#       7 )
#       9 print('items:', len(ws.item_ids))
#      10 print('lenses:', len(ws.lens_names))
#
# File ~/Documents/GitHub/RSS_Feeds/analysis_module/explore.py:46, in load_workspace(scores_path, lenses_path, aggregation)
#      43 lens_file = Path(lenses_path)
#      45 lens_defs, rubric_to_lens = load_lenses(lens_file)
# ---> 46 scores = load_scores(score_file, rubric_to_lens)
#      47 if not scores:
#      48     raise ValueError("No usable scores found. Check scores.json and lenses path.")
#
# File ~/Documents/GitHub/RSS_Feeds/analysis_module/core.py:169, in load_scores(path, rubric_to_lens)
#     168 def load_scores(path: Path, rubric_to_lens: dict[str, str]) -> list[RubricScore]:
# --> 169     payload = json.loads(path.read_text(encoding="utf-8"))
#     170     if not isinstance(payload, list):
#     171         raise ValueError("Scores file must be a JSON array.")
#
# File /opt/homebrew/Cellar/python@3.13/3.13.12_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/pathlib/_local.py:546, in Path.read_text(self, encoding, errors, newline)
#     543 # Call io.text_encoding() here to ensure any warning is raised at an
#     544 # appropriate stack level.
#     545 encoding = io.text_encoding(encoding)
# --> 546 return PathBase.read_text(self, encoding, errors, newline)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.12_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/pathlib/_abc.py:632, in PathBase.read_text(self, encoding, errors, newline)
#     628 def read_text(self, encoding=None, errors=None, newline=None):
#     629     """
#     630     Open the file in text mode, read it, and close the file.
#     631     """
# --> 632     with self.open(mode='r', encoding=encoding, errors=errors, newline=newline) as f:
#     633         return f.read()
#
# File /opt/homebrew/Cellar/python@3.13/3.13.12_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/pathlib/_local.py:537, in Path.open(self, mode, buffering, encoding, errors, newline)
#     535 if "b" not in mode:
#     536     encoding = io.text_encoding(encoding)
# --> 537 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/alexstevens/Documents/GitHub/RSS_Feeds/scores.json'

# %%
from analysis_module import article_records

records = article_records(ws, normalized=True, include_incomplete=True)
records[:2]
